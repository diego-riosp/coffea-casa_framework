# %%
# %%time
from coffea import processor
from coffea.nanoevents import NanoAODSchema, NanoEventsFactory
from constructors.filesets import BuildFileset, rucio_queries, filesets
from constructors.corrections.sets import corrections
from loadmodule import loadModule, loadAll
from dask.distributed import Client
import mplhep as hep
import matplotlib.pyplot as plt
loadAll("constructors/utils/util_functions.py")
client = Client("tls://localhost:8786") #load local dask client (HTCondor) coffea-casa
MuonProcessor = loadModule("constructors/processors/muon_processor.py") #load processor instance through absolute path
test_fileset = getattr(filesets,'test_fileset')
fileset = loadJson("constructors/filesets/ZToMuMu_fileset.json")


dask_run = processor.Runner( #this is new runner function for coffea 2025.10
    executor=processor.DaskExecutor(client=client, compression=None), #execute via dask workers
    schema=NanoAODSchema,
    chunksize=100_000,
    skipbadfiles=True,
    savemetrics=False,
)
year = "2022"
workflow_path = "workflow.yaml"
corrections = corrections.corr_dict(year)
#histograms = dask_run(test_fileset, processor_instance=MuonProcessor(year, corrections.corr_dict(year)))
histograms = dask_run(test_fileset, processor_instance=MuonProcessor(workflow_path, year, corrections))
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# CPU times: user 4.66 s, sys: 462 ms, total: 5.12 s
# Wall time: 22 s

# %%
import mplhep as hep
import matplotlib.pyplot as plt
#bkg = ["DYJetsToLL", "DYJetsToLL_HT", "TTbar", "SingleTop", "Diboson"]
#data = ["DoubleMuon", "SingleMuon", "EGamma", "Muon"]

bkg = ["DYJetsToLL"]
data = ["DoubleMuon"]

bkg_hists = [histograms[p]["mass"] for p in bkg]
data_hist = sum(histograms[p]["mass"] for p in data)

hep.histplot(bkg_hists, stack=True, label=bkg)
hep.histplot(data_hist,histtype="errorbar",label="Data",color="black")

plt.legend()
plt.show()

# %%
from coffea.util import save
save(histograms, "output.coffea")

# %%
from coffea.util import load
histograms = load("output.coffea")

# %%
output
# Out:
# {'DoubleMuon': {'mass': Hist(Regular(30, 60, 120, name='mass', label='mμμ [GeV]'), storage=Weight()) # Sum: WeightedSum(value=287105, variance=287105),
#   'nevents': 287105},
#  'SingleMuon': {'mass': Hist(Regular(30, 60, 120, name='mass', label='mμμ [GeV]'), storage=Weight()) # Sum: WeightedSum(value=266301, variance=266301),
#   'nevents': 266301},
#  'Muon': {'mass': Hist(Regular(30, 60, 120, name='mass', label='mμμ [GeV]'), storage=Weight()) # Sum: WeightedSum(value=3.77751e+06, variance=3.77751e+06),
#   'nevents': 3777513},
#  'EGamma': {'mass': Hist(Regular(30, 60, 120, name='mass', label='mμμ [GeV]'), storage=Weight()) # Sum: WeightedSum(value=2473, variance=2473),
#   'nevents': 2473},
#  'DYJetsToLL': {'mass': Hist(Regular(30, 60, 120, name='mass', label='mμμ [GeV]'), storage=Weight()) # Sum: WeightedSum(value=148623, variance=9458.08),
#   'nevents': 5297442},
#  'DYJetsToLL_HT': {'mass': Hist(Regular(30, 60, 120, name='mass', label='mμμ [GeV]'), storage=Weight()) # Sum: WeightedSum(value=9327.65, variance=5.36146e+07),
#   'nevents': 265},
#  'TTbar': {'mass': Hist(Regular(30, 60, 120, name='mass', label='mμμ [GeV]'), storage=Weight()) # Sum: WeightedSum(value=51018.6, variance=6385.57),
#   'nevents': 568653},
#  'SingleTop': {'mass': Hist(Regular(30, 60, 120, name='mass', label='mμμ [GeV]'), storage=Weight()) # Sum: WeightedSum(value=7095.56, variance=1880.13),
#   'nevents': 61562},
#  'Diboson': {'mass': Hist(Regular(30, 60, 120, name='mass', label='mμμ [GeV]'), storage=Weight()) # Sum: WeightedSum(value=1.81859e+06, variance=1.65848e+08),
#   'nevents': 149544}}

# %% [markdown]
# ## To generate rucio fileset

# %%
# %%time
query_name = 'ZToMuMu'
testFileset = getattr(filesets,'test_fileset') #load test fileset
rucioQuery = getattr(rucio_queries, query_name) #load rucio_query for ZToMuMu files
fileset = BuildFileset().buildFileset(rucioQuery,query_name); #build fileset with DataDiscoveryCLI and convert
                                                              #internally filesets_vailable.json.gz to python dict
